# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('classic')
plt.rc('figure', facecolor='w', figsize=(10,10))
plt.rc('axes', labelsize=24)
plt.rc('axes', titlesize=24)

# %%
tick_labels = ['nominal', 'kinematic BDT', 'VBF BDT', 'kinematic fit', 'photon pt cut']
x_vals = [1, 2, 3, 4, 5]
y_vals = [5.3, 4.92, 4.09, 3.51, 3.36]

# %%
fig, ax = plt.subplots()
ax.plot(x_vals, y_vals, marker='.', color='k', markersize=16)
ax.set_xlim(0., 6.)
ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels(tick_labels)
ax.set_ylabel('Ex￼pected Limit ($\sf m_{H} = 125\, GeV$)')
plt.savefig('expected_limit_optimization.png', dpi=500)
